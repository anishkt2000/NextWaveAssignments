# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, sin, cos, sqrt, atan2

# Sample data
data = {
    'id': [1, 2, 3, 4],
    'event': ['SOSP', 'EOSP', 'SOSP', 'EOSP'],
    'dateStamp': [43831, 43831, 43832, 43832],
    'timeStamp': [0.708333, 0.791667, 0.333333, 0.583333],
    'voyage_From': ['Port A', 'Port A', 'Port B', 'Port B'],
    'lat': [34.0522, 34.0522, 36.7783, 36.7783],
    'lon': [-118.2437, -118.2437, -119.4179, -119.4179],
    'imo_num': ['9434761', '9434761', '9434761', '9434761'],
    'voyage_Id': ['6', '6', '6', '6'],
    'allocatedVoyageId': [None, None, None, None]
}

df = pd.DataFrame(data)

def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Earth's radius in kilometers

    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance_km = R * c
    return distance_km * 0.539957  # Convert to nautical miles

# Calculate event_datetime
df['event_datetime'] = df['dateStamp'] + df['timeStamp']

# Sort by event_datetime
df = df.sort_values('event_datetime')

# Calculate duration and previous event details
df['duration'] = df['event_datetime'].diff()
df['prev_lat'] = df['lat'].shift()
df['prev_lon'] = df['lon'].shift()
df['prev_event'] = df['event'].shift()

# Determine segment type
df['segment_type'] = np.where(df['event'] == 'SOSP', 'Sailing',
                              np.where(df['event'] == 'EOSP', 'Port Stay', 'Unknown'))

# Calculate distance travelled
df['distance_travelled'] = np.where(
    (df['prev_event'] == 'EOSP') & (df['event'] == 'SOSP'),
    df.apply(lambda row: haversine_distance(row['prev_lat'], row['prev_lon'], row['lat'], row['lon']), axis=1),
    0
)

# Calculate cumulative times
df['cumulative_sailing_time'] = np.where(df['segment_type'] == 'Sailing', df['duration'], 0).cumsum()
df['cumulative_port_time'] = np.where(df['segment_type'] == 'Port Stay', df['duration'], 0).cumsum()

# Visualize the voyage timeline
plt.figure(figsize=(12, 6))
for i, row in df.iterrows():
    if row['segment_type'] == 'Sailing':
        plt.plot([row['event_datetime'], row['event_datetime'] + row['duration']], 
                 [row['voyage_From'], df.iloc[i+1]['voyage_From']], 'b-', linewidth=2)
    else:
        plt.plot([row['event_datetime'], row['event_datetime'] + row['duration']], 
                 [row['voyage_From'], row['voyage_From']], 'r-', linewidth=4)

plt.xlabel('Date-Time')
plt.ylabel('Port')
plt.title('Voyage Timeline')
plt.grid(True)
plt.tight_layout()
plt.show()

# Display results
print(df[['id', 'event', 'event_datetime', 'voyage_From', 'lat', 'lon', 'segment_type', 
          'duration', 'distance_travelled', 'cumulative_sailing_time', 'cumulative_port_time']])
# Out:
#    id event  event_datetime voyage_From      lat       lon segment_type  \
# 0   1  SOSP    43831.708333      Port A  34.0522 -118.2437      Sailing
# 1   2  EOSP    43831.791667      Port A  34.0522 -118.2437    Port Stay
# 2   3  SOSP    43832.333333      Port B  36.7783 -119.4179      Sailing
# 3   4  EOSP    43832.583333      Port B  36.7783 -119.4179    Port Stay
#
#    duration  distance_travelled  cumulative_sailing_time  cumulative_port_time
# 0       NaN            0.000000                      NaN              0.000000
# 1  0.083334            0.000000                      NaN              0.083334
# 2  0.541666          173.463101                      NaN              0.083334
# 3  0.250000            0.000000                      NaN              0.333334

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, sin, cos, sqrt, atan2

# Function to calculate distance between two points on Earth
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Earth's radius in kilometers

    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance_km = R * c
    return distance_km * 0.539957  # Convert to nautical miles

# Sample data (replace this with actual data loading from a database)
data = [
    (1, 'SOSP', 43831.708333, 'Port A', 34.0522, -118.2437, '9434761', '6', None),
    (2, 'EOSP', 43831.791667, 'Port A', 34.0522, -118.2437, '9434761', '6', None),
    (3, 'SOSP', 43832.333333, 'Port B', 36.7783, -119.4179, '9434761', '6', None),
    (4, 'EOSP', 43832.583333, 'Port B', 36.7783, -119.4179, '9434761', '6', None)
]

# Create DataFrame
df = pd.DataFrame(data, columns=['id', 'event', 'datetime', 'voyage_From', 'lat', 'lon', 'imo_num', 'voyage_Id', 'allocatedVoyageId'])

# Convert datetime to proper format
df['datetime'] = pd.to_datetime(df['datetime'].apply(lambda x: (x - 25569) * 86400), unit='s')

# Sort by datetime
df = df.sort_values('datetime')

# Calculate time differences
df['duration'] = df['datetime'].diff().dt.total_seconds() / 3600  # in hours

# Calculate distances
df['distance_nautical_miles'] = df.apply(lambda row: haversine_distance(
    row['lat'], row['lon'],
    df.loc[df.index[df.index.get_loc(row.name) - 1], 'lat'] if row.name > 0 else row['lat'],
    df.loc[df.index[df.index.get_loc(row.name) - 1], 'lon'] if row.name > 0 else row['lon']
), axis=1)

# Identify voyage segments
df['segment_type'] = df['event'].map({'SOSP': 'Sailing', 'EOSP': 'Port Stay'})

# Calculate cumulative times
df['cumulative_sailing_hours'] = (df['duration'] * (df['segment_type'] == 'Sailing')).cumsum()
df['cumulative_port_hours'] = (df['duration'] * (df['segment_type'] == 'Port Stay')).cumsum()

# Visualization
plt.figure(figsize=(12, 6))
plt.plot(df['datetime'], df['cumulative_sailing_hours'], label='Cumulative Sailing Time')
plt.plot(df['datetime'], df['cumulative_port_hours'], label='Cumulative Port Time')
plt.scatter(df['datetime'], df['cumulative_sailing_hours'] + df['cumulative_port_hours'], 
            c=df['segment_type'].map({'Sailing': 'blue', 'Port Stay': 'red'}), 
            s=100, zorder=5)

for _, row in df.iterrows():
    plt.annotate(f"{row['event']} at {row['voyage_From']}", 
                 (row['datetime'], row['cumulative_sailing_hours'] + row['cumulative_port_hours']),
                 xytext=(0, 10), textcoords='offset points', ha='center', va='bottom',
                 bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
                 arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.xlabel('Date and Time')
plt.ylabel('Cumulative Hours')
plt.title('Voyage Timeline')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Print results
print(df.to_string(index=False))
# Out:
#  id event                      datetime voyage_From     lat       lon imo_num voyage_Id allocatedVoyageId  duration  distance_nautical_miles segment_type  cumulative_sailing_hours  cumulative_port_hours
#   1  SOSP 2020-01-01 16:59:59.971200256      Port A 34.0522 -118.2437 9434761         6              None       NaN                 0.000000      Sailing                       NaN                    NaN
#   2  EOSP 2020-01-01 19:00:00.028799744      Port A 34.0522 -118.2437 9434761         6              None  2.000016                 0.000000    Port Stay                  0.000000               2.000016
#   3  SOSP 2020-01-02 07:59:59.971200256      Port B 36.7783 -119.4179 9434761         6              None 12.999984               173.463101      Sailing                 12.999984               2.000016
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, sin, cos, sqrt, atan2

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Earth's radius in kilometers

    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance_km = R * c
    return distance_km * 0.539957  # Convert to nautical miles

# %%
df = pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv('data.csv')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, sin, cos, sqrt, atan2
from datetime import datetime, timedelta

def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Earth's radius in kilometers
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance_km = R * c
    return distance_km * 0.539957  # Convert to nautical miles

# Sample data
data = [
    (1, 'SOSP', 43831.708333, 'Port A', 34.0522, -118.2437, '9434761', '6', None),
    (2, 'EOSP', 43831.791667, 'Port A', 34.0522, -118.2437, '9434761', '6', None),
    (3, 'SOSP', 43832.333333, 'Port B', 36.7783, -119.4179, '9434761', '6', None),
    (4, 'EOSP', 43832.583333, 'Port B', 36.7783, -119.4179, '9434761', '6', None),
    (5, 'SOSP', 43833.000000, 'Port C', 37.7749, -122.4194, '9434761', '7', None),
    (6, 'EOSP', 43833.250000, 'Port C', 37.7749, -122.4194, '9434761', '7', None)
]

df = pd.DataFrame(data, columns=['id', 'event', 'datetime', 'voyage_From', 'lat', 'lon', 'imo_num', 'voyage_Id', 'allocatedVoyageId'])

# Filter for specific vessel and voyage
df = df[(df['imo_num'] == '9434761') & (df['voyage_Id'] == '6') & (df['allocatedVoyageId'].isnull())]

# Convert Excel date to UTC datetime
df['utc_datetime'] = df['datetime'].apply(lambda x: datetime(1899, 12, 30) + timedelta(days=x))

# Sort by UTC datetime
df = df.sort_values('utc_datetime')

# Calculate time differences
df['duration'] = df['utc_datetime'].diff()
df['duration_hours'] = df['duration'] / pd.Timedelta(hours=1)

# Calculate distances
df['distance_nautical_miles'] = df.apply(lambda row: haversine_distance(
    row['lat'], row['lon'],
    df.loc[df.index[df.index.get_loc(row.name) - 1], 'lat'] if row.name > df.index[0] else row['lat'],
    df.loc[df.index[df.index.get_loc(row.name) - 1], 'lon'] if row.name > df.index[0] else row['lon']
), axis=1)

# Identify voyage segments
df['segment_type'] = df['event'].map({'SOSP': 'Sailing', 'EOSP': 'Port Stay'})

# Calculate cumulative times
df['cumulative_sailing_hours'] = (df['duration_hours'] * (df['segment_type'] == 'Sailing')).cumsum()
df['cumulative_port_hours'] = (df['duration_hours'] * (df['segment_type'] == 'Port Stay')).cumsum()

# Calculate time durations between key events
df['time_since_last_event'] = df['duration_hours']
df['time_since_last_SOSP'] = df.groupby((df['event'] == 'SOSP').cumsum())['duration_hours'].cumsum()
df['time_since_last_EOSP'] = df.groupby((df['event'] == 'EOSP').cumsum())['duration_hours'].cumsum()

# Visualization
plt.figure(figsize=(12, 6))
plt.plot(df['utc_datetime'], df['cumulative_sailing_hours'], label='Cumulative Sailing Time')
plt.plot(df['utc_datetime'], df['cumulative_port_hours'], label='Cumulative Port Time')
plt.scatter(df['utc_datetime'], df['cumulative_sailing_hours'] + df['cumulative_port_hours'], 
            c=df['segment_type'].map({'Sailing': 'blue', 'Port Stay': 'red'}), 
            s=100, zorder=5)

for _, row in df.iterrows():
    plt.annotate(f"{row['event']} at {row['voyage_From']}\n{row['utc_datetime'].strftime('%Y-%m-%d %H:%M:%S')}", 
                 (row['utc_datetime'], row['cumulative_sailing_hours'] + row['cumulative_port_hours']),
                 xytext=(0, 10), textcoords='offset points', ha='center', va='bottom',
                 bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
                 arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.xlabel('Date and Time (UTC)')
plt.ylabel('Cumulative Hours')
plt.title('Voyage Timeline for IMO 9434761, Voyage 6')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Print results
print(df.to_string(index=False))
# Out:
#  id event     datetime voyage_From     lat       lon imo_num voyage_Id allocatedVoyageId               utc_datetime               duration  duration_hours  distance_nautical_miles segment_type  cumulative_sailing_hours  cumulative_port_hours  time_since_last_event  time_since_last_SOSP  time_since_last_EOSP
#   1  SOSP 43831.708333      Port A 34.0522 -118.2437 9434761         6              None 2020-01-01 16:59:59.971200                    NaT             NaN                 0.000000      Sailing                       NaN                    NaN                    NaN                   NaN                   NaN
#   2  EOSP 43831.791667      Port A 34.0522 -118.2437 9434761         6              None 2020-01-01 19:00:00.028800 0 days 02:00:00.057600        2.000016                 0.000000    Port Stay                  0.000000               2.000016               2.000016              2.000016              2.000016
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, sin, cos, sqrt, atan2
from datetime import datetime, timedelta

def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Earth's radius in kilometers
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance_km = R * c
    return distance_km * 0.539957  # Convert to nautical miles

# Sample data
data = [
    (1, 'SOSP', 43831.708333, 'Port A', 34.0522, -118.2437, '9434761', '6', None),
    (2, 'EOSP', 43831.791667, 'Port B', 36.7783, -119.4179, '9434761', '6', None),
    (3, 'SOSP', 43832.333333, 'Port B', 36.7783, -119.4179, '9434761', '6', None),
    (4, 'EOSP', 43832.583333, 'Port C', 37.7749, -122.4194, '9434761', '6', None),
    (5, 'SOSP', 43833.000000, 'Port C', 37.7749, -122.4194, '9434761', '6', None),
    (6, 'EOSP', 43833.250000, 'Port D', 32.7157, -117.1611, '9434761', '6', None)
]

df = pd.DataFrame(data, columns=['id', 'event', 'datetime', 'voyage_From', 'lat', 'lon', 'imo_num', 'voyage_Id', 'allocatedVoyageId'])

# Filter for specific vessel and voyage
df = df[(df['imo_num'] == '9434761') & (df['voyage_Id'] == '6') & (df['allocatedVoyageId'].isnull())]

# Convert Excel date to UTC datetime
df['utc_datetime'] = df['datetime'].apply(lambda x: datetime(1899, 12, 30) + timedelta(days=x))

# Sort by UTC datetime
df = df.sort_values('utc_datetime')

# Identify voyage stages
df['stage'] = (df['event'] == 'SOSP').cumsum()
df['stage_type'] = df['event'].map({'SOSP': 'Sea Passage', 'EOSP': 'Port Stay'})

# Calculate time differences
df['duration'] = df['utc_datetime'].diff()
df['duration_hours'] = df['duration'] / pd.Timedelta(hours=1)

# Calculate distances
df['distance_nautical_miles'] = df.apply(lambda row: haversine_distance(
    row['lat'], row['lon'],
    df.loc[df.index[df.index.get_loc(row.name) - 1], 'lat'] if row.name > df.index[0] else row['lat'],
    df.loc[df.index[df.index.get_loc(row.name) - 1], 'lon'] if row.name > df.index[0] else row['lon']
), axis=1)

# Calculate cumulative times and distances for each stage
df['cumulative_hours'] = df.groupby('stage')['duration_hours'].cumsum()
df['cumulative_distance'] = df.groupby('stage')['distance_nautical_miles'].cumsum()

# Calculate stage statistics
stage_stats = df.groupby('stage').agg({
    'stage_type': 'first',
    'voyage_From': lambda x: f"{x.iloc[0]} to {x.iloc[-1]}",
    'duration_hours': 'sum',
    'distance_nautical_miles': 'sum',
    'utc_datetime': ['min', 'max']
}).reset_index()

stage_stats.columns = ['stage', 'stage_type', 'route', 'duration_hours', 'distance_nautical_miles', 'start_time', 'end_time']

# Visualization
plt.figure(figsize=(12, 6))

for stage, group in df.groupby('stage'):
    color = 'blue' if group['stage_type'].iloc[0] == 'Sea Passage' else 'red'
    plt.plot(group['utc_datetime'], group['cumulative_hours'], color=color, label=f"Stage {stage}: {group['stage_type'].iloc[0]}")
    plt.scatter(group['utc_datetime'], group['cumulative_hours'], color=color)

for _, row in df.iterrows():
    plt.annotate(f"{row['event']} at {row['voyage_From']}\n{row['utc_datetime'].strftime('%Y-%m-%d %H:%M:%S')}", 
                 (row['utc_datetime'], row['cumulative_hours']),
                 xytext=(0, 10), textcoords='offset points', ha='center', va='bottom',
                 bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
                 arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.xlabel('Date and Time (UTC)')
plt.ylabel('Cumulative Hours')
plt.title('Voyage Timeline for IMO 9434761, Voyage 6')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Print results
print("Voyage Events:")
print(df.to_string(index=False))
print("\nVoyage Stage Statistics:")
print(stage_stats.to_string(index=False))
# Out:
# Voyage Events:
#  id event     datetime voyage_From     lat       lon imo_num voyage_Id allocatedVoyageId               utc_datetime  stage  stage_type               duration  duration_hours  distance_nautical_miles  cumulative_hours  cumulative_distance
#   1  SOSP 43831.708333      Port A 34.0522 -118.2437 9434761         6              None 2020-01-01 16:59:59.971200      1 Sea Passage                    NaT             NaN                 0.000000               NaN             0.000000
#   2  EOSP 43831.791667      Port B 36.7783 -119.4179 9434761         6              None 2020-01-01 19:00:00.028800      1   Port Stay 0 days 02:00:00.057600        2.000016               173.463101          2.000016           173.463101
#   3  SOSP 43832.333333      Port B 36.7783 -119.4179 9434761         6              None 2020-01-02 07:59:59.971200      2 Sea Passage 0 days 12:59:59.942400       12.999984                 0.000000         12.999984             0.000000
# ...
